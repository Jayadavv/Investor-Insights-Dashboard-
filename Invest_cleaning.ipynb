# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data_set 2 - Copy.csv")
df.head(4)
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# 0        Monthly  20%-30%  Mutual Fund                   Retirement Plan
# 1         Weekly  20%-30%  Mutual Fund                       Health Care
# ...

# %%
# To get information related data type,non-null values and total entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
# to know total rows and columns
df.shape
# Out:
# (40, 24)

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
#Descriptive Statistics
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      25
# Female    15
# Name: count, dtype: int64

# %%
gender_counts = df['gender'].value_counts()
plt.figure(figsize=(7, 7))  # Optional: Set the figure size
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'orange'])
plt.title('Gender Distribution')
plt.show()

# %%
## Statistics for numerical columns
numerical_columns = df.select_dtypes(include=[np.number])
numerical_summary = numerical_columns.describe()
numerical_summary
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
# Most Preferred Investment Avenue
preferred_investment = df['Avenue'].value_counts().idxmax()
print(f'Most preferred investment avenue: {preferred_investment}')
# Out:
# Most preferred investment avenue: Mutual Fund

# %%
# Reasons for Investment
selected_columns = df.loc[:, 'What are your savings objectives?':'Reason_FD']

combined_reasons = selected_columns.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)


from collections import Counter

word_counts = Counter(" ".join(combined_reasons).split())


recurring_reasons = word_counts.most_common(10)
print("Top recurring reasons:")
for reason, count in recurring_reasons:
    print(f"{reason}: {count}")
# Out:
# Top recurring reasons:
# Returns: 68
# Capital: 30
# Appreciation: 30
# Assured: 26
# Retirement: 24
# Plan: 24
# Better: 24
# Risk: 19
# Free: 19
# Fixed: 18

# %%
# Savings Objectives
savings_objectives = df['What are your savings objectives?'].value_counts()
savings_objectives.reset_index()
# Out:
#   What are your savings objectives?  count
# 0                   Retirement Plan     24
# 1                       Health Care     13
# 2                         Education      3

# %%
# Common Information Sources
info_sources = df['Source'].value_counts()
info_sources.reset_index()
# Out:
#                      Source  count
# 0     Financial Consultants     16
# 1  Newspapers and Magazines     14
# 2                Television      6
# 3                  Internet      4

# %%
# Investment Duration

# Defining the mapping for ranges to numeric values
duration_mapping = {
    'less than 1 year': 0.5,
    '1-3 years': 2,
    '3-5 years': 4,
    'more than 5 years': 6
}

# Mapping the values to the 'Duration' column
df['Investment Duration (Numeric)'] = df['Duration'].map(duration_mapping)

# Calculate the mean
avg_duration = df['Investment Duration (Numeric)'].mean()
print(f'Average investment duration (in years): {avg_duration:.2f}')

# Determine the most frequent range
most_frequent = df['Duration'].value_counts().idxmax()
print(f'Most frequent investment duration range: {most_frequent}')
# Out:
# Average investment duration (in years): 3.03
# Most frequent investment duration range: 3-5 years

# %%
expectations = df['Expect'].value_counts()
expectations.reset_index()
# Out:
#     Expect  count
# 0  20%-30%     32
# 1  30%-40%      5
# 2  10%-20%      3

# %%
# Extract relevant columns: age, Duration, and Expect
# Handle categorical columns by encoding them into numerical values
data_selected = df[['age', 'Duration', 'Expect']]

# Encoding 'Duration' and 'Expect' as they are categorical
# Example mappings: 
# 'Duration': {'Less than 1 year': 0, '1-3 years': 1, '3-5 years': 2, 'More than 5 years': 3}
# 'Expect': {'10%-20%': 0.15, '20%-30%': 0.25, ...}

duration_mapping = {'Less than 1 year': 0, '1-3 years': 1, '3-5 years': 2, 'More than 5 years': 3}
expect_mapping = {'10%-20%': 0.15, '20%-30%': 0.25, '30%-40%': 0.35, '40%-50%': 0.45}

data_selected['Duration'] = data_selected['Duration'].map(duration_mapping)
data_selected['Expect'] = data_selected['Expect'].map(expect_mapping)

# Drop rows with missing values after encoding
data_selected = data_selected.dropna()

# Calculate correlation matrix
correlation_matrix = data_selected.corr()

# Visualize the correlation matrix using seaborn
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Selected Features')
plt.show()

correlation_matrix
# Out:
# C:\Users\aakan\AppData\Local\Temp\ipykernel_19040\1255794334.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_selected['Duration'] = data_selected['Duration'].map(duration_mapping)
# C:\Users\aakan\AppData\Local\Temp\ipykernel_19040\1255794334.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_selected['Expect'] = data_selected['Expect'].map(expect_mapping)
#                age  Duration    Expect
# age       1.000000  0.076515 -0.089606
# ...
